# %%
import numpy as np
import matplotlib.pyplot as plt
import torchvision.transforms.functional as F
import torch
from torchvision.transforms import InterpolationMode
import cv2

# %%
asda = np.load(r"C:\Users\Administrator\Desktop\asda.png.npy")
print(asda.shape)
asda = np.squeeze(asda)
plt.figure()
plt.imshow(asda)
# Out:
# (128, 128)

# %%
asda =np.load(r"D:\brainweb_corediff_all\L004_dose005_slice050_sim0_img.npy")[None,...]
print(asda.shape)
asda = np.squeeze(asda)
plt.figure()
plt.imshow(asda)
asda_da = cv2.resize(asda, (128, 128), interpolation=cv2.INTER_NEAREST)
plt.figure()
plt.imshow(asda_da)
# Out:
# (1, 256, 256)

# %%
asda =np.load(r"C:\Users\Administrator\Desktop\clean.png.npy")
plt.figure()
plt.imshow(asda)

plt.figure()
asda =np.load(r"C:\Users\Administrator\Desktop\noisy.png.npy")
plt.imshow(asda)

# %%
asda.max()
# Out:
# 4.471774
